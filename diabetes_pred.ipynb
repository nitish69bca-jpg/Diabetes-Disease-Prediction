# %% [markdown]
# ## Diabetes Disease Prediction
#
# ### 1. Get data
# ### 2. Preprocessing Data
# ### 3. Train test and split
# ### 4. Train and evaluate model
# ### 5. Create website

# %% [markdown]
# ## 1. import libraries

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 2. Load Dataset

# %%
df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## Preprocess data

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df_mean = df.groupby('Outcome').mean()
df_mean
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# ## 3. Split Features & Target

# %%
X = df.drop("Outcome", axis=1)
y = df['Outcome']

# %%
X.shape
# Out:
# (768, 8)

# %%
y.shape
# Out:
# (768,)

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# ## 4. Train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2, stratify= y)

# %%
print(X_train.shape,y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (614, 8) (614,)
# (154, 8) (154,)

# %%
y_train
# Out:
# 619    1
# 329    0
# 13     1
# 476    1
# 45     1
#       ..
# 303    1
# 592    1
# 559    0
# 725    0
# 253    0
# Name: Outcome, Length: 614, dtype: int64

# %% [markdown]
# ## 5. Feature Scaling

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## 6. Train Logistic Regression Model

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ## 7. Model Accuracy

# %%
X_train_pred = model.predict(X_train_scaled)
X_test_pred = model.predict(X_test_scaled)

# %%
train_acc = accuracy_score(X_train_pred, y_train)
test_acc = accuracy_score(X_test_pred, y_test)
print("training accuracy : ", train_acc)
print("test_accuracy : ", test_acc)
# Out:
# training accuracy :  0.7850162866449512
# test_accuracy :  0.7597402597402597

# %% [markdown]
# ## Prediction System

# %%
input_data = (9,156,86,28,155,34.3,1.189,42)
input_data_array = np.asarray(input_data)
input_data_reshaped = input_data_array.reshape(1,-1)

input_data_scaled = scaler.transform(input_data_reshaped)   #Scale input
prediction = model.predict(input_data_scaled)

print("Prediction : ", prediction)

if prediction[0]==1 :
    print("Person is Diabetic")
else :
    print("Person is NOT diabetic")
# Out:
# Prediction :  [1]
# Person is Diabetic
# C:\Users\chaur\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
df.sample(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 430            2       99              0              0        0  22.2
# 31             3      158             76             36      245  31.6
# 195            5      158             84             41      210  39.4
# 333           12      106             80              0        0  23.6
# 276            7      106             60             24        0  26.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 430                     0.108   23        0
# 31                      0.851   28        1
# 195                     0.395   29        1
# 333                     0.137   44        0
# 276                     0.296   29        1

# %%
import pickle
pickle.dump(model, open("diabetesfile.pkl", "wb"))

# %%
pickle.dump(scaler, open("diabetes_scaler.pkl", "wb"))

# %%
pickle.dump(df, open("diabetes_df.pkl", "wb"))

# %%
pickle.dump(df_mean, open("diabetes_mean.pkl", "wb"))
pickle.dump(train_acc, open("diabetes_train_acc.pkl", "wb"))
pickle.dump(test_acc, open("diabetes_test_acc.pkl", "wb"))
